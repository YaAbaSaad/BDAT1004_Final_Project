# %%
import requests

api_key = '3d34ac462feff5af263db85a10d59884'  
base_url = "http://api.aviationstack.com/v1/flights"
params = {
    'access_key': api_key,
    'flight_status': 'active'  
}

response = requests.get(base_url, params=params)
data = response.json()

# Print the retrieved data
print(data)
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 13438}, 'data': [{'flight_date': '2023-12-13', 'flight_status': 'active', 'departure': {'airport': 'Guiyang', 'timezone': 'Asia/Shanghai', 'iata': 'KWE', 'icao': 'ZUGY', 'terminal': 'T2', 'gate': None, 'delay': 17, 'scheduled': '2023-12-13T11:55:00+00:00', 'estimated': '2023-12-13T11:55:00+00:00', 'actual': '2023-12-13T12:11:00+00:00', 'estimated_runway': '2023-12-13T12:11:00+00:00', 'actual_runway': '2023-12-13T12:11:00+00:00'}, 'arrival': {'airport': 'Wuxi', 'timezone': 'Asia/Shanghai', 'iata': 'WUX', 'icao': 'ZSWX', 'terminal': 'T2', 'gate': None, 'baggage': '9', 'delay': None, 'scheduled': '2023-12-13T14:30:00+00:00', 'estimated': '2023-12-13T14:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': '9 Air Co', 'iata': 'AQ', 'icao': 'JYH'}, 'flight': {'number': '1331', 'iata': 'AQ1331', 'icao': 'JYH1331', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2023-12-13', 'flight_status': 'active', 'departure': {'airport': 'Guiyang', 'timezone': 'Asia/Shanghai', 'iata': 'KWE', 'icao': 'ZUGY', 'terminal': 'T3', 'gate': '408', 'delay': 1, 'scheduled': '2023-12-13T12:00:00+00:00', 'estimated': '2023-12-13T12:00:00+00:00', 'actual': '2023-12-13T12:00:00+00:00', 'estimated_runway': '2023-12-13T12:00:00+00:00', 'actual_runway': '2023-12-13T12:00:00+00:00'}, 'arrival': {'airport': 'Guangzhou Baiyun International', 'timezone': 'Asia/Shanghai', 'iata': 'CAN', 'icao': 'ZGGG', 'terminal': '2', 'gate': None, 'baggage': '35', 'delay': None, 'scheduled': '2023-12-13T13:40:00+00:00', 'estimated': '2023-12-13T13:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}, 'flight': {'number': '4311', 'iata': 'KL4311', 'icao': 'KLM4311', 'codeshared': {'airline_name': 'china southern airlines', 'airline_iata': 'cz', 'airline_icao': 'csn', 'flight_number': '6412', 'flight_iata': 'cz6412', 'flight_icao': 'csn6412'}}, 'aircraft': None, 'live': None}, {'flight_date': '2023-12-13', 'flight_status': 'active', 'departure': {'airport': 'Guiyang', 'timezone': 'Asia/Shanghai', 'iata': 'KWE', 'icao': 'ZUGY', 'terminal': 'T3', 'gate': '408', 'delay': 1, 'scheduled': '2023-12-13T12:00:00+00:00', 'estimated': '2023-12-13T12:00:00+00:00', 'actual': '2023-12-13T12:00:00+00:00', 'estimated_runway': '2023-12-13T12:00:00+00:00', 'actual_runway': '2023-12-13T12:00:00+00:00'}, 'arrival': {'airport': 'Guangzhou Baiyun International', 'timezone': 'Asia/Shanghai', 'iata': 'CAN', 'icao': 'ZGGG', 'terminal': '2', 'gate': None, 'baggage': '35', 'delay': None, 'scheduled': '2023-12-13T13:40:00+00:00', 'estimated': '2023-12-13T13:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Southern Airlines', 'iata': 'CZ', 'icao': 'CSN'}, 'flight': {'number': '6412', 'iata': 'CZ6412', 'icao': 'CSN6412', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2023-12-13', 'flight_status': 'active', 'departure': {'airport': 'Guiyang', 'timezone': 'Asia/Shanghai', 'iata': 'KWE', 'icao': 'ZUGY', 'terminal': 'T2', 'gate': '206', 'delay': 11, 'scheduled': '2023-12-13T12:05:00+00:00', 'estimated': '2023-12-13T12:05:00+00:00', 'actual': '2023-12-13T12:15:00+00:00', 'estimated_runway': '2023-12-13T12:15:00+00:00', 'actual_runway': '2023-12-13T12:15:00+00:00'}, 'arrival': {'airport': 'Shanghai Hongqiao International', 'timezone': 'Asia/Shanghai', 'iata': 'SHA', 'icao': 'ZSSS', 'terminal': '2', 'gate': None, 'baggage': '25', 'delay': None, 'scheduled': '2023-12-13T14:30:00+00:00', 'estimated': '2023-12-13T14:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Juneyao Airlines', 'iata': 'HO', 'icao': 'DKH'}, 'flight': {'number': '1208', 'iata': 'HO1208', 'icao': 'DKH1208', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2023-12-13', 'flight_status':  ...

# %%
pip install pymongo dnspython
# Out:
# Collecting pymongo
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/c8/1a/1ba5578cc3acc8ef0dfd6eb9385f9c4b0fe3039665af93bcf062c34fcdb6/pymongo-4.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pymongo-4.6.1-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Collecting dnspython
#   Obtaining dependency information for dnspython from https://files.pythonhosted.org/packages/f6/b4/0a9bee52c50f226a3cbfb54263d02bb421c7f2adc136520729c2c689c1e5/dnspython-2.4.2-py3-none-any.whl.metadata
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Downloading pymongo-4.6.1-cp311-cp311-win_amd64.whl (472 kB)
#    ---------------------------------------- 0.0/472.7 kB ? eta -:--:--
#    --------------------------------------- 472.7/472.7 kB 14.5 MB/s eta 0:00:00
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ---------------------------------------- 0.0/300.4 kB ? eta -:--:--
#    --------------------------------------- 300.4/300.4 kB 18.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from pymongo import MongoClient

# MongoDB Atlas setup
mongo_conn_string = 'mongodb+srv://adejumoabdulazeez:aade6850@cluster0.ogpfaff.mongodb.net/?retryWrites=true&w=majority'  
client = MongoClient(mongo_conn_string)
db = client['flight_data_db']
collection = db['flights']

# Fetch data from Aviationstack API
api_key = '3d34ac462feff5af263db85a10d59884'
base_url = "http://api.aviationstack.com/v1/flights"
params = {'access_key': api_key}
response = requests.get(base_url, params=params)
data = response.json()

# Process and store in MongoDB Atlas
for flight in data['data']:
    collection.insert_one(flight)
